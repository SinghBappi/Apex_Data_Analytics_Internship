# %%
import pandas as pd

# %%
df = pd.read_csv("Final_Sales_Pipeline.csv")
df.head(11)
# Out:
#    opportunity_id      sales_agent         product     account deal_stage  \
# 0        1C1I7A6R      Moses Frase  GTX Plus Basic     Cancity        won
# 1        Z063OYW0  Darcel Schlecht          GTXPro       Isdom        won
# 2        EC4QE1BX  Darcel Schlecht      MG Special     Cancity        won
# 3        MV1LWRNH      Moses Frase       GTX Basic     Codehow        won
# 4        PE84CX4O        Zane Levy       GTX Basic      Hatfan        won
# 5        ZNBS69V1    Anna Snelling      MG Special    Ron-tech        won
# 6        9ME3374G   Vicki Laflamme      MG Special     J-Texon        won
# 7        7GN8Q4LL   Markita Hansen       GTX Basic      Cheers        won
# 8        OLK9LKZB  Niesha Huffines  GTX Plus Basic    Zumgoity        won
# 9        HAXMC4IX   James Ascencio     MG Advanced         NaN   engaging
# 10       NL3JZH1Z    Anna Snelling      MG Special  Bioholding        won
#
#    engage_date  close_date  close_value
# ...

# %%
df.shape
# Out:
# (8800, 8)

# %%
df.columns
# Out:
# Index(['opportunity_id', 'sales_agent', 'product', 'account', 'deal_stage',
#        'engage_date', 'close_date', 'close_value'],
#       dtype='object')

# %%
df.describe()
# Out:
#         close_value
# count   8800.000000
# mean    1136.992500
# std     2123.528615
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%     1085.250000
# max    30288.000000

# %%
df['deal_stage'].value_counts()
# Out:
# deal_stage
# won            4238
# lost           2473
# engaging       1589
# prospecting     500
# Name: count, dtype: int64

# %%
df['deal_stage'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='deal_stage'>

# %%
df['close_value'].describe()
# Out:
# count     8800.000000
# mean      1136.992500
# std       2123.528615
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%       1085.250000
# max      30288.000000
# Name: close_value, dtype: float64

# %%
df['close_value'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['close_date'] = pd.to_datetime(df['close_date'])

# %%
df['month'] = df['close_date'].dt.to_period('M')

# %%
df.groupby('month')['close_value'].sum().plot()
# Out:
# <Axes: xlabel='month'>

# %%
df.groupby('deal_stage')['close_value'].sum()
# Out:
# deal_stage
# engaging              0.0
# lost                  0.0
# prospecting           0.0
# won            10005534.0
# Name: close_value, dtype: float64

# %%
df.head()
# Out:
#   opportunity_id      sales_agent         product  account deal_stage  \
# 0       1C1I7A6R      Moses Frase  GTX Plus Basic  Cancity        won
# 1       Z063OYW0  Darcel Schlecht          GTXPro    Isdom        won
# 2       EC4QE1BX  Darcel Schlecht      MG Special  Cancity        won
# 3       MV1LWRNH      Moses Frase       GTX Basic  Codehow        won
# 4       PE84CX4O        Zane Levy       GTX Basic   Hatfan        won
#
#   engage_date close_date  close_value    month
# 0  2016-10-20 2017-03-01       1054.0  2017-03
# 1  2016-10-25 2017-03-11       4514.0  2017-03
# 2  2016-10-25 2017-03-07         50.0  2017-03
# 3  2016-10-25 2017-03-09        588.0  2017-03
# 4  2016-10-25 2017-03-02        517.0  2017-03

# %%
df.groupby('month').size().plot()
# Out:
# <Axes: xlabel='month'>
